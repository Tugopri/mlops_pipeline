# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dates = "C:\M52.0\mlops_pipeline\Base_de_datos1.csv"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6044\3808679132.py:1: SyntaxWarning: invalid escape sequence '\M'
#   dates = "C:\M52.0\mlops_pipeline\Base_de_datos1.csv"

# %%
df = pd.read_csv(dates)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10763 entries, 0 to 10762
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tipo_credito                   10763 non-null  int64
#  1   fecha_prestamo                 10763 non-null  str
#  2   capital_prestado               10763 non-null  int64
#  3   plazo_meses                    10763 non-null  int64
#  4   edad_cliente                   10763 non-null  int64
#  5   tipo_laboral                   10763 non-null  str
#  6   salario_cliente                10763 non-null  int64
#  7   total_otros_prestamos          10763 non-null  int64
#  8   cuota_pactada                  10763 non-null  int64
#  9   puntaje                        10763 non-null  str
#  10  puntaje_datacredito            10757 non-null  float64
#  11  cant_creditosvigentes          10763 non-null  int64
#  12  huella_consulta                10763 non-null  int64
# ...

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# tipo_credito                        0
# fecha_prestamo                      0
# capital_prestado                    0
# plazo_meses                         0
# edad_cliente                        0
# tipo_laboral                        0
# salario_cliente                     0
# total_otros_prestamos               0
# cuota_pactada                       0
# puntaje                             0
# puntaje_datacredito                 6
# cant_creditosvigentes               0
# huella_consulta                     0
# saldo_mora                        156
# saldo_total                       156
# saldo_principal                   405
# saldo_mora_codeudor               590
# creditos_sectorFinanciero           0
# creditos_sectorCooperativo          0
# creditos_sectorReal                 0
# promedio_ingresos_datacredito    2930
# tendencia_ingresos               2932
# Pago_atiempo                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['tipo_credito', 'fecha_prestamo', 'capital_prestado', 'plazo_meses',
#        'edad_cliente', 'tipo_laboral', 'salario_cliente',
#        'total_otros_prestamos', 'cuota_pactada', 'puntaje',
#        'puntaje_datacredito', 'cant_creditosvigentes', 'huella_consulta',
#        'saldo_mora', 'saldo_total', 'saldo_principal', 'saldo_mora_codeudor',
#        'creditos_sectorFinanciero', 'creditos_sectorCooperativo',
#        'creditos_sectorReal', 'promedio_ingresos_datacredito',
#        'tendencia_ingresos', 'Pago_atiempo'],
#       dtype='str')

# %%
df = df.drop_duplicates()

# %%
pd.crosstab(df["edad_cliente"], df["tipo_laboral"])
# Out:
# tipo_laboral  Empleado  Independiente
# edad_cliente
# 19                   1              0
# 20                  14             10
# 21                  35              8
# 22                  60             17
# 23                  85             24
# 24                 123             33
# 25                 113             45
# 26                 168             64
# 27                 179             57
# 28                 203             60
# 29                 222             69
# 30                 197             78
# 31                 219             80
# 32                 204             88
# 33                 171             96
# 34                 200             81
# 35                 191             96
# 36                 213            106
# 37                 233            111
# 38                 223            116
# 39                 216            105
# 40                 212            134
# 41                 201            131
# ...

# %%
df["puntaje_datacredito"].value_counts()
# Out:
# puntaje_datacredito
# 0.0      145
# 802.0    102
# 783.0    102
# 791.0    100
# 801.0     98
#         ...
# 690.0      1
# 359.0      1
# 474.0      1
# 442.0      1
# 480.0      1
# Name: count, Length: 315, dtype: int64

# %%
df["tipo_credito"].value_counts()
# Out:
# tipo_credito
# 4     7747
# 9     2876
# 10     116
# 6       21
# 7        2
# 68       1
# Name: count, dtype: int64

# %%
df['tipo_laboral'].value_counts().plot(kind='bar')
plt.title("Tipo Laboral")
plt.show()
