# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Base_de_datos.xlsx")

# %%
df.info()

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())

# %%
df = df.fillna(np.nan)
df['columna_numerica'] = pd.to_numeric(df['columna_numerica'], errors='coerce')

# %% [markdown]
# Analisis Univariable dristribuciones....

# %%
df.describe().T

# %%
df.hist(figsize=(12, 10), bins=20)
plt.tight_layout()
plt.show()

# %%
df['variable_categorica'].value_counts()

# %% [markdown]
# anailiss bivariable y multivariable...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()
